# %% [markdown]
# # ASSIGNEMENT-2 K.V.SAKETH

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
print(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
df = pd.read_csv("titanic.csv")

# Plot the histogram
plt.hist(df['class'], color='red')

# Set the labels and title
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Histogram of Titanic Passenger Classes')

# Display the histogram
plt.show()

# %%
categories = list(df['embarked'].unique())
value_counts = df['embarked'].value_counts()

# %%
plt.pie(value_counts,labels=categories[:-1], autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x29af63c65f0>,
#   <matplotlib.patches.Wedge at 0x29af63c6170>,
#   <matplotlib.patches.Wedge at 0x29af63c4340>],
#  [Text(-0.7128398214280038, 0.8377704870586524, 'S'),
#   Text(0.4614522559226597, -0.9985298270476893, 'C'),
#   Text(1.0595276168013974, -0.29563698894954155, 'Q')],
#  [Text(-0.38882172077891114, 0.4569657202138104, '72.44'),
#   Text(0.25170123050326887, -0.5446526329351032, '18.90'),
#   Text(0.577924154618944, -0.16125653942702264, '8.66')])

# %%
survival_counts = df.groupby('pclass')['survived'].value_counts().unstack()

# Plotting the stacked bar chart
survival_counts.plot(kind='bar', stacked=True)

# Adding labels and a title
plt.xlabel('Passenger Class')
plt.ylabel('Survival Count')
plt.title('Survival Count by Passenger Class')

# Display the stacked bar chart
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x='pclass', y='fare', data=df)
plt.title('Fare by Passenger Class')
plt.show()

# %%
sns.scatterplot(x='age', y='fare', data=df, hue='survived')
plt.title('Age vs. Fare (colored by survival)')
plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\SAKETH\AppData\Local\Temp\ipykernel_7312\1729857075.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['deck'].fillna("Not Applicable", inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male            deck  embark_town alive  alone
# 0      man        True  Not Applicable  Southampton    no  False
# 1    woman       False               C    Cherbourg   yes  False
# 2    woman       False  Not Applicable  Southampton   yes   True
# 3    woman       False               C  Southampton   yes  False
# 4      man        True  Not Applicable  Southampton    no   True
# ..     ...         ...             ...          ...   ...    ...
# 886    man        True  Not Applicable  Southampton    no   True
# 887  woman       False               B  Southampton   yes   True
# 888  woman       False  Not Applicable  Southampton    no  False
# 889    man        True               C    Cherbourg   yes   True
# 890    man        True  Not Applicable   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male            deck  embark_town alive  alone
# 0     Third    man        True  Not Applicable  Southampton    no  False
# 1     First  woman       False               C    Cherbourg   yes  False
# 2     Third  woman       False  Not Applicable  Southampton   yes   True
# 3     First  woman       False               C  Southampton   yes  False
# 4     Third    man        True  Not Applicable  Southampton    no   True
# ..      ...    ...         ...             ...          ...   ...    ...
# 886  Second    man        True  Not Applicable  Southampton    no   True
# 887   First  woman       False               B  Southampton   yes   True
# 888   Third  woman       False  Not Applicable  Southampton    no  False
# 889   First    man        True               C    Cherbourg   yes   True
# 890   Third    man        True  Not Applicable   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3 - Q1
lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR
outliers = df[(df['fare'] < lower_fence) | (df['fare'] > upper_fence)]

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv("titanic.csv")

# Calculate the lower and upper fences
lower_fence = df['fare'].quantile(0.25) - 1.5 * (df['fare'].quantile(0.75) - df['fare'].quantile(0.25))
upper_fence = df['fare'].quantile(0.75) + 1.5 * (df['fare'].quantile(0.75) - df['fare'].quantile(0.25))

# Cap the values of 'fare' column within the range
df['fare'] = np.where((df['fare'] < lower_fence), lower_fence, df['fare'])
df['fare'] = np.where((df['fare'] > upper_fence), upper_fence, df['fare'])

# %%
df['fare']
# Out:
# 0       7.2500
# 1      65.6344
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
#After removing outliers and replacing
sns.boxplot(x='fare', data=df)
plt.show()

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['who']= label_encoder.fit_transform(df['who'])
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  65.6344        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# 0      1        True  NaN  Southampton    no  False
# 1      2       False    C    Cherbourg   yes  False
# 2      2       False  NaN  Southampton   yes   True
# 3      2       False    C  Southampton   yes  False
# 4      1        True  NaN  Southampton    no   True
# ..   ...         ...  ...          ...   ...    ...
# 886    1        True  NaN  Southampton    no   True
# 887    2       False    B  Southampton   yes   True
# 888    2       False  NaN  Southampton    no  False
# 889    1        True    C    Cherbourg   yes   True
# 890    1        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
x = df.drop(columns="survived")
y=df['survived']
x
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    1
# 1         1  female  38.0      1      0  65.6344        C   First    2
# 2         3  female  26.0      0      0   7.9250        S   Third    2
# 3         1  female  35.0      1      0  53.1000        S   First    2
# 4         3    male  35.0      0      0   8.0500        S   Third    1
# ..      ...     ...   ...    ...    ...      ...      ...     ...  ...
# 886       2    male  27.0      0      0  13.0000        S  Second    1
# 887       1  female  19.0      0      0  30.0000        S   First    2
# 888       3  female   NaN      1      2  23.4500        S   Third    2
# 889       1    male  26.0      0      0  30.0000        C   First    1
# 890       3    male  32.0      0      0   7.7500        Q   Third    1
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
min_value = df['fare'].min()
max_value = df['fare'].max()
df['scaled_fare']  = (df['fare'] - min_value) / (max_value - min_value)

# Assign the scaled column back to the dataset
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  65.6344        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone  scaled_fare
# 0      1        True  NaN  Southampton    no  False     0.110460
# 1      2       False    C    Cherbourg   yes  False     1.000000
# 2      2       False  NaN  Southampton   yes   True     0.120745
# 3      2       False    C  Southampton   yes  False     0.809027
# 4      1        True  NaN  Southampton    no   True     0.122649
# ..   ...         ...  ...          ...   ...    ...          ...
# 886    1        True  NaN  Southampton    no   True     0.198067
# 887    2       False    B  Southampton   yes   True     0.457077
# 888    2       False  NaN  Southampton    no  False     0.357282
# 889    1        True    C    Cherbourg   yes   True     0.457077
# 890    1        True  NaN   Queenstown    no   True     0.118078
#
# [891 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  who  \
# 331       1    male  45.5      0      0  28.5000        S   First    1
# 733       2    male  23.0      0      0  13.0000        S  Second    1
# 382       3    male  32.0      0      0   7.9250        S   Third    1
# 704       3    male  26.0      1      0   7.8542        S   Third    1
# 813       3  female   6.0      4      2  31.2750        S   Third    0
# ..      ...     ...   ...    ...    ...      ...      ...     ...  ...
# 106       3  female  21.0      0      0   7.6500        S   Third    2
# 270       1    male   NaN      0      0  31.0000        S   First    1
# 860       3    male  41.0      2      0  14.1083        S   Third    1
# 435       1  female  14.0      1      2  65.6344        S   First    0
# 102       1    male  21.0      0      1  65.6344        S   First    1
#
#      adult_male deck  embark_town alive  alone
# 331        True    C  Southampton    no   True
# 733        True  NaN  Southampton    no   True
# 382        True  NaN  Southampton    no   True
# 704        True  NaN  Southampton    no  False
# 813       False  NaN  Southampton    no  False
# ..          ...  ...          ...   ...    ...
# 106       False  NaN  Southampton   yes   True
# 270        True  NaN  Southampton    no   True
# 860        True  NaN  Southampton    no  False
# 435       False    B  Southampton   yes  False
# 102        True    D  Southampton    no  False
#
# [712 rows x 14 columns]

# %%
y_train
# Out:
# 331    0
# 733    0
# 382    0
# 704    0
# 813    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: survived, Length: 712, dtype: int64
